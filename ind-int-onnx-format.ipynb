# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 555.0 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import shutil
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
shutil.copy(
    "/kaggle/input/datasets/nikita041/best-model/best.pt",
    "/kaggle/working/best.pt"
)

model = YOLO("/kaggle/working/best.pt")
model.export(format="onnx", opset=12, simplify=True, imgsz=640)
# Out:
# Ultralytics 8.4.86 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# YOLO11n summary (fused): 101 layers, 2,588,587 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/kaggle/working/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 37, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 659ms
# Prepared 2 packages in 858ms
# Installed 2 packages in 15ms
#  + onnxruntime==1.27.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 2.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 12...
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 4.5s, saved as '/kaggle/working/best.onnx' (10.1 MB)
#
# Export complete (5.1s)
# Results saved to /kaggle/working/best.onnx
# ...
